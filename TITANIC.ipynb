# %%
import pandas as pd

# %%
df=pd.read_csv('Titanic-Dataset.csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.describe(include='all')
# Out:
#         PassengerId    Survived      Pclass                     Name   Sex  \
# count    891.000000  891.000000  891.000000                      891   891
# unique          NaN         NaN         NaN                      891     2
# top             NaN         NaN         NaN  Braund, Mr. Owen Harris  male
# freq            NaN         NaN         NaN                        1   577
# mean     446.000000    0.383838    2.308642                      NaN   NaN
# std      257.353842    0.486592    0.836071                      NaN   NaN
# min        1.000000    0.000000    1.000000                      NaN   NaN
# 25%      223.500000    0.000000    2.000000                      NaN   NaN
# 50%      446.000000    0.000000    3.000000                      NaN   NaN
# 75%      668.500000    1.000000    3.000000                      NaN   NaN
# max      891.000000    1.000000    3.000000                      NaN   NaN
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.drop("Cabin",inplace=True,axis=1)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked
# 0      0         A/5 21171   7.2500        S
# 1      0          PC 17599  71.2833        C
# 2      0  STON/O2. 3101282   7.9250        S
# 3      0            113803  53.1000        S
# 4      0            373450   8.0500        S

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Embarked         2
# dtype: int64

# %%
df=df.dropna()

# %%
df.isna().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
import matplotlib.pyplot as plt
import numpy as np
from collections import Counter

# %%
p1,p2=Counter(df['Sex'])['male'],Counter(df['Sex'])['female']

# %%
plt.bar(np.arange(2)-0.2,[p1,p2],0.4)
plt.bar(np.arange(2)+0.2,[df['Survived'].groupby(df['Sex']).count()[0],df['Survived'].groupby(df['Sex']).count()[0]],0.4)
plt.xticks(np.arange(2)+(0.01/2),['male','female'])
plt.legend(['no of men and women before','no of men and women after'])

# %%
df['Age'].groupby(df['Sex']).mean()
# Out:
# Sex
# female    27.745174
# male      30.726645
# Name: Age, dtype: float64

# %%
df['Fare'].groupby(df['Embarked']).mean()
# Out:
# Embarked
# C    68.296767
# Q    18.265775
# S    27.476284
# Name: Fare, dtype: float64

# %%
plt.bar(np.arange(3),[df['Fare'].groupby(df['Embarked']).mean()[0],df['Fare'].groupby(df['Embarked']).mean()[1],df['Fare'].groupby(df['Embarked']).mean()[2]],tick_label=['C','Q','S'])
# Out:
# <BarContainer object of 3 artists>

# %%
Counter(df['Pclass'])
# Out:
# Counter({3: 355, 1: 184, 2: 173})

# %%
sns.violinplot(df['Fare'])
# Out:
# <Axes: >

# %%
sns.pairplot(df)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
cat_df=df.select_dtypes(include='object')

# %%
le=LabelEncoder()
for i in cat_df.columns:
    df[i]=le.fit_transform(cat_df[i])

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  Name  Sex   Age  SibSp  Parch  Ticket  \
# 0            1         0       3   103    1  22.0      1      0     407
# 1            2         1       1   179    0  38.0      1      0     470
# 2            3         1       3   317    0  26.0      0      0     531
# 3            4         1       1   247    0  35.0      1      0      39
# 4            5         0       3    15    1  35.0      0      0     372
#
#       Fare  Embarked
# 0   7.2500         2
# 1  71.2833         0
# 2   7.9250         2
# 3  53.1000         2
# 4   8.0500         2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 712 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  712 non-null    int64
#  1   Survived     712 non-null    int64
#  2   Pclass       712 non-null    int64
#  3   Name         712 non-null    int32
#  4   Sex          712 non-null    int32
#  5   Age          712 non-null    float64
#  6   SibSp        712 non-null    int64
#  7   Parch        712 non-null    int64
#  8   Ticket       712 non-null    int32
#  9   Fare         712 non-null    float64
#  10  Embarked     712 non-null    int32
# dtypes: float64(2), int32(4), int64(5)
# memory usage: 71.8 KB

# %%
from sklearn.model_selection import train_test_split

# %%
x=df.loc[:,['Pclass','Name','Sex','Age','SibSp','Parch','Ticket','Embarked']]
y=df['Survived']
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=101,test_size=0.2)

# %%
from sklearn.feature_selection import SelectKBest,f_classif

# %%
sb=SelectKBest(f_classif,k=5)
x_new=sb.fit_transform(x_train,y_train)

# %%
x_new
# Out:
# array([[  2.,   0.,   0., 433.,   2.],
#        [  3.,   0.,   2., 273.,   2.],
#        [  3.,   0.,   0., 156.,   0.],
#        ...,
#        [  1.,   1.,   0.,  41.,   2.],
#        [  3.,   1.,   0., 214.,   2.],
#        [  3.,   1.,   0., 295.,   2.]])

# %%
col=sb.get_support(indices=True)
for i in col:
    print(x.columns[i])
# Out:
# Pclass
# Sex
# Parch
# Ticket
# Embarked
